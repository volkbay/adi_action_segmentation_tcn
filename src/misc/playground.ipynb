# %%
import sys
sys.path.append('../')
import torch
from tcn import TCNv9, TCNv10
import ai8x
from distiller import apputils

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
ai8x.set_device(device=85, simulate=False, round_avg=False)
# Out:
# Configuring device: MAX78000, simulate=False.

# %%
import distiller
print(distiller.__file__)
# Out:
# /home/volkanokbay/prj/ai8x-training/distiller/distiller/__init__.py

# %%
input_size = (64, 64)
model_in = TCNv9(num_classes=4, input_size=input_size, num_channels=48, num_frames_model=16, bias=True, dropout=0.5, initUniform=True).to(device)
model_out, sch, opt, epoch = apputils.load_checkpoint(model=model_in, model_device='cuda', chkpt_file='../sav/model9_trainNo39_at_epoch_22_with_acc_70_34_checkpoint.pth.tar')
# Out:
# I - Initializing model TCNv9

# %%
model_out.state_dict
# Out:
# <bound method Module.state_dict of TCNv9(
#   (prep0): FusedConv2dBNReLU(
#     (activate): ReLU(inplace=True)
#     (op): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=False, track_running_stats=True)
#     (calc_out_shift): OutputShiftSqueeze()
#     (calc_weight_scale): One()
#     (scale): Scaler()
#     (calc_out_scale): OutputScale()
#     (quantize_weight): Empty()
#     (quantize_bias): Empty()
#     (clamp_weight): Empty()
#     (clamp_bias): Empty()
#     (quantize): Empty()
#     (clamp): Clamp()
#     (quantize_pool): Empty()
#     (clamp_pool): Empty()
#   )
#   (conv0): FusedConv2dBNReLU(
#     (activate): ReLU(inplace=True)
#     (op): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=False, track_running_stats=True)
#     (calc_out_shift): OutputShiftSqueeze()
#     (calc_weight_scale): One()
#     (scale): Scaler()
# ...

# %%
model_train = TCNv10(num_classes=4, input_size=input_size, num_channels=48, num_frames_model=16, bias=True, dropout=0.5, initUniform=True).to(device)
miss, unex = model_train.load_state_dict(model_out.state_dict(), strict=False)
# Out:
# I - Initializing model TCNv10

# %%
params = model_train.named_parameters

# %%
for p in params():
    if p[0] not in miss:
        print(p[1].requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# ...
